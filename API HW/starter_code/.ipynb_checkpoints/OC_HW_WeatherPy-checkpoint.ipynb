# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * The coldest max temperatures currently are in the norther hemisphere, above the equator. We have multiple cities that have a max temperature of (-)20 degrees or less.
# * As was expected, our data pull shows that as you get closer to the equator, the highest temperatures out of our random cities pull are near the equator
# * We did not see a strong correlation between the city latitude and the humidity.This was only more evident after a closer analysis of our graph where we notice an outlier. After further investigation, we see that it was a single city that showed a humidity of 290, Talara, Peru. We removed the city, and could further illustrate the lack of correlation between the two values.
# * Our scatter plots for wind speed and cloudiness also show the lack of correlation between latitude and their values.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
import openweathermapy.core as owm
from requests.exceptions import HTTPError


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
city_weather_data = "../CSV/city_weather.data.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#learning how the np.random.uniform works for a sample of 10
#test np.random for lat and long
lat1 = np.random.uniform(low = 0.000, high = 90, size = 10 )
print(lat1)
long1 = np.random.uniform(low = 0.000, high = 180.000, size = 10)
print(long1)
# Out:
# [31.83509251  6.41179003 87.7893724  20.98990635  6.49110684  9.06065931
#  68.30376383 73.1470469   5.42781169  0.8078896 ]
# [ 86.54955379  59.36843953  73.11369913 107.73622777 179.74777161
#  115.88753802 178.94892395  97.99855262 112.88142245 117.51843243]

# %%
#testing the zip of the two variables, convert to a list to print
#lat_long1 = []
lat_long1 = list(zip(lat1, long1))
lat_long1
# Out:
# [(31.83509251431927, 86.54955379285609),
#  (6.4117900278813975, 59.3684395308525),
#  (87.78937239915369, 73.11369912672858),
#  (20.98990634525424, 107.73622777399521),
#  (6.4911068367949785, 179.74777161147458),
#  (9.060659308312577, 115.8875380234253),
#  (68.30376383440067, 178.94892394576965),
#  (73.14704689914049, 97.9985526151227),
#  (5.427811689767132, 112.88142245336324),
#  (0.8078896027289328, 117.51843243427346)]

# %%
#not part of homework
#test code to learn more about citipy, could not find more reference material for other calls you can make beside nearest city, name
cities1 = []
for x in lat_long1:
    city = citipy.nearest_city(x[0],x[1]).city_name
    if city not in cities1:
        cities1.append(city)

# %%
#print(cities1)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)


# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %%
print(cities)
# Out:
# ['chuy', 'rikitea', 'derac', 'jamestown', 'taolanaro', 'severo-kurilsk', 'tura', 'bluff', 'carnarvon', 'kodiak', 'mar del plata', 'busselton', 'ushuaia', 'atuona', 'mega', 'ribeira grande', 'ballina', 'vuktyl', 'talnakh', 'hilo', 'mattru', 'burica', 'adrar', 'tasiilaq', 'alofi', 'chokurdakh', 'hobart', 'comodoro rivadavia', 'georgetown', 'te anau', 'san-pedro', 'pevek', 'albany', 'cabo san lucas', 'hermanus', 'port elizabeth', 'aklavik', 'ust-kamchatsk', 'hoi an', 'tiksi', 'pangnirtung', 'diu', 'port alfred', 'east london', 'gornyye klyuchi', 'kutum', 'victoria', 'viligili', 'daru', 'tsihombe', 'qaanaaq', 'punta arenas', 'jardim', 'umm durman', 'vila velha', 'nara', 'kapaa', 'sola', 'amderma', 'lata', 'kaitangata', 'baghmara', 'the woodlands', 'solnechnyy', 'mataura', 'saskylakh', 'geraldton', 'katsuura', 'new norfolk', 'hambantota', 'deputatskiy', 'castro', 'palabuhanratu', 'afua', 'divnomorskoye', 'carutapera', 'ilulissat', 'buchanan', 'sao filipe', 'jiroft', 'guacimo', 'mount isa', 'russell', 'xichang', 'borgarnes', 'fairbanks', 'grand river south east', 'buin', 'butaritari', 'saint-philippe', 'samusu', 'northam', 'vallenar', 'tandil', 'tuatapere', 'mandal', 'norman wells', 'nha trang', 'west fargo', 'vao', 'vaini', 'hamilton', 'dzaoudzi', 'sioux lookout', 'alexandria', 'barrow', 'makakilo city', 'tezu', 'garden city', 'moose factory', 'esperance', 'uri', 'zatyshshya', 'samalaeulu', 'bindura', 'klaksvik', 'high level', 'grand centre', 'bloemfontein', 'angatuba', 'avarua', 'stoyba', 'attawapiskat', 'baculin', 'cape town', 'meulaboh', 'yarada', 'pontian kecil', 'beloha', 'maningrida', 'boyolangu', 'port hardy', 'sabang', 'verkhnevilyuysk', 'jacqueville', 'pirovskoye', 'cayenne', 'dikson', 'lokosovo', 'antalaha', 'puerto ayora', 'bengkulu', 'cherskiy', 'bireun', 'narsaq', 'prince rupert', 'umm lajj', 'praia da vitoria', 'vestmannaeyjar', 'fray bentos', 'provideniya', 'gravdal', 'sur', 'wuwei', 'pisco', 'nizhneyansk', 'yuzha', 'airai', 'suslovo', 'bambanglipuro', 'luderitz', 'yar-sale', 'mys shmidta', 'alyangula', 'macapa', 'broken hill', 'barentsburg', 'illoqqortoormiut', 'mahon', 'nikolskoye', 'manono', 'swan hill', 'zhigansk', 'porto novo', 'umzimvubu', 'amahai', 'korla', 'merauke', 'wasilla', 'vostok', 'bredasdorp', 'lagoa', 'erzin', 'lavrentiya', 'tessalit', 'mogadishu', 'pontes e lacerda', 'longyearbyen', 'bonthe', 'walvis bay', 'tuktoyaktuk', 'jiddah', 'santiago del estero', 'nishihara', 'ayan', 'nyurba', 'ulaangom', 'ponta do sol', 'toucheng', 'yulara', 'belushya guba', 'vysokogornyy', 'westport', 'cabra', 'farafangana', 'saint-joseph', 'saint anthony', 'bereda', 'maputo', 'kolyvan', 'hithadhoo', 'akureyri', 'saldanha', 'edgewater', 'ptuj', 'yaan', 'yablonovo', 'nome', 'wenling', 'mahebourg', 'pilao arcado', 'vardo', 'macia', 'esik', 'ucluelet', 'qingquan', 'quelimane', 'tautira', 'lompoc', 'coffs harbour', 'ormara', 'arrecife', 'mrirt', 'marechal deodoro', 'qui nhon', 'guerrero negro', 'beringovskiy', 'ingham', 'susehri', 'lagos', 'torbay', 'vaitupu', 'solenzo', 'santa maria', 'zakharovo', 'salaverry', 'faanui', 'khatanga', 'naryan-mar', 'shingu', 'ati', 'krasnoselkup', 'rabaul', 'husavik', 'olafsvik', 'codrington', 'lazaro cardenas', 'mozarlandia', 'peleduy', 'mandera', 'la palma', 'andenes', 'bargal', 'san carlos de bariloche', 'kirakira', 'sitka', 'yaya', 'baherden', 'indian head', 'abu samrah', 'george', 'halalo', 'abrau-dyurso', 'flinders', 'arraial do cabo', 'alghero', 'zeya', 'rocha', 'yellowknife', 'komsomolskiy', 'goderich', 'abu kamal', 'banepa', 'tumannyy', 'makat', 'norrkoping', 'turayf', 'iqaluit', 'villa carlos paz', 'saint-francois', 'alice springs', 'bubaque', 'deqing', 'huancabamba', 'ivanava', 'nanortalik', 'udachnyy', 'chancay', 'kibakwe', 'grand-santi', 'behbahan', 'vila franca do campo', 'bourail', 'bundaberg', 'rovaniemi', 'lafia', 'xinxiang', 'omboue', 'kahului', 'thompson', 'jumla', 'bathsheba', 'okhotsk', 'ancud', 'roald', 'upernavik', 'kloulklubed', 'fujin', 'dhanwar', 'arlit', 'shiyan', 'kiet ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create a settings object with your API key and preferred units
settings = {"units": "imperial", "appid": api_key}

# %%
#method #1 without using the openweathermapy wrapper
#create empty lists to be used in data frame

#weather_data1=[]
#temperature = []
#humidity = []
#cloudiness = []
#windspeed = []
#lat = []
#long = []
#city_name = []

#create a record1 counter
#create variables for the units of measurement(fahrenheit = imperial)
#create variable for units
#create url, it is less clean than the openweather wrapper

#record1 = 0
#units = "imperial"

#url = 'http://api.openweathermap.org/data/2.5/weather?q='

#run a loop for all the cities in our list. 
#append the new data to our empty lists listed above
#for city in cities:
#    city_weather = requests.get(url+city+"&appid="+api_key+"&units="+units).json()
    
#    if city_weather["cod"] == 200:
#        weather_data1.append(city_weather)
#        temperature.append(city_weather["main"]["temp"])
#        humidity.append(city_weather["main"]["humidity"])
#        cloudiness.append(city_weather["clouds"]["all"])
#        windspeed.append(city_weather["wind"]["speed"])
#        lat.append(city_weather["coord"]["lat"])
#        long.append(city_weather["coord"]["lon"])
#        city_name.append(city)
#        record1 += 1
#        print(f'Processing Record {record1} of Set 1 | {city}')
#    else:
#        print(f'City was not found! Skipping.')
#print out once the for loop is complete        
#print("Data download complete.")

# %%
#test out the list of weather data that was appended
#weather_data1

# %%
#using the openweathermapy.core wrapper
#create empty weather_data list to hold info for each city, don't think really need this
#create record counter
#create a summary list to use in wrapper to pull only the information we need

weather_data = []
record = 0
summary = ["name","sys.country","dt","main.temp_max","main.humidity","clouds.all","wind.speed","coord.lat","coord.lon"]

#create for loop with a try and except to help deal with the HTTP:Not Found error, and continue once it gets it

for city in cities:
    try:
        city_weather = owm.get_current(city, **settings)
        data = city_weather(*summary)
        weather_data.append(data)
        record += 1 
        print(f'Processing Record {record} of Set 1 | {city}')
    except Exception as e:
        print(f'The city of {city} was not found! Skipping. Error code was {e}')
        continue
print(f'The OpenWeather API data dump is complete.')
# Out:
# Processing Record 1 of Set 1 | chuy
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | derac
# Processing Record 4 of Set 1 | jamestown
# The city of taolanaro was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 5 of Set 1 | severo-kurilsk
# Processing Record 6 of Set 1 | tura
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | mega
# Processing Record 15 of Set 1 | ribeira grande
# Processing Record 16 of Set 1 | ballina
# Processing Record 17 of Set 1 | vuktyl
# Processing Record 18 of Set 1 | talnakh
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | mattru
# The city of burica was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 21 of Set 1 | adrar
# Processing Record 22 of Set 1 | tasiilaq
# Processing Record 23 of Set 1 | alofi
# Processing Record 24 of Set 1 | chokurdakh
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | comodoro rivadavia
# Processing Record 27 of Set 1 | georgetown
# Processing Record 28 of Set 1 | te anau
# Processing Record 29 of Set 1 | san-pedro
# Processing Record 30 of Set 1 | pevek
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | cabo san lucas
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | aklavik
# The city of ust-kamchatsk was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 36 of Set 1 | hoi an
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | pangnirtung
# Processing Record 39 of Set 1 | diu
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | east london
# Processing Record 42 of Set 1 | gornyye klyuchi
# Processing Record 43 of Set 1 | kutum
# Processing Record 44 of Set 1 | victoria
# The city of viligili was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 45 of Set 1 | daru
# The city of tsihombe was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | jardim
# The city of umm durman was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 49 of Set 1 | vila velha
# Processing Record 50 of Set 1 | nara
# Processing Record 51 of Set 1 | kapaa
# Processing Record 52 of Set 1 | sola
# The city of amderma was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 53 of Set 1 | lata
# Processing Record 54 of Set 1 | kaitangata
# Processing Record 55 of Set 1 | baghmara
# Processing Record 56 of Set 1 | the woodlands
# Processing Record 57 of Set 1 | solnechnyy
# Processing Record 58 of Set 1 | mataura
# Processing Record 59 of Set 1 | saskylakh
# Processing Record 60 of Set 1 | geraldton
# Processing Record 61 of Set 1 | katsuura
# Processing Record 62 of Set 1 | new norfolk
# Processing Record 63 of Set 1 | hambantota
# Processing Record 64 of Set 1 | deputatskiy
# Processing Record 65 of Set 1 | castro
# The city of palabuhanratu was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 66 of Set 1 | afua
# Processing Record 67 of Set 1 | divnomorskoye
# Processing Record 68 of Set 1 | carutapera
# Processing Record 69 of Set 1 | ilulissat
# Processing Record 70 of Set 1 | buchanan
# Processing Record 71 of Set 1 | sao filipe
# The city of jiroft was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 72 of Set 1 | guacimo
# Processing Record 73 of Set 1 | mount isa
# Processing Record 74 of Set 1 | russell
# Processing Record 75 of Set 1 | xichang
# Processing Record 76 of Set 1 | borgarnes
# Processing Record 77 of Set 1 | fairbanks
# The city of grand river south east was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 78 of Set 1 | buin
# Processing Record 79 of Set 1 | butaritari
# Processing Record 80 of Set 1 | saint-philippe
# The city of samusu was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 81 of Set 1 | northam
# Processing Record 82 of Set 1 | vallenar
# Processing Record 83 of Set 1 | tandil
# Processing Record 84 of Set 1 | tuatapere
# Processing Record 85 of Set 1 | mandal
# Processing Record 86 of Set 1 | norman wells
# Processing Record 87 of Set 1 | nha trang
# Processing Record 88 of Set 1 | west fargo
# Processing Record 89 of Set 1 | vao
# Processing Record 90 of Set 1 | vaini
# Processing Record 91 of Set 1 | hamilton
# Processing Record 92 of Set 1 | dzaoudzi
# Processing Record 93 of Set 1 | sioux lookout
# Processing Record 94 of Set 1 | alexandria
# Processing Record 95 of Set 1 | barrow
# Processing Record 96 of Set 1 | makakilo city
# Processing Record 97 of Set 1 | tezu
# Processing Record 98 of Set 1 | garden city
# Processing Record 99 of Set 1 | moose factory
# Processing Record 100 of Set 1 | esperance
# Processing Record 101 of Set 1 | uri
# Processing Record 102 of Set 1 | zatyshshya
# The city of samalaeulu was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 103 of Set 1 | bindura
# Processing Record 104 of Set 1 | klaksvik
# Processing Record 105 of Set 1 | high level
# The city of grand centre was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 106 of Set 1 | bloemfontein
# Processing Record 107 of Set 1 | angatuba
# Processing Record 108 of Set 1 | avarua
# The city of stoyba was not found! Skipping. Error code was HTTP Error 404: Not Found
# The city of attawapiskat was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 109 of Set 1 | baculin
# Processing Record 110 of Set 1 | cape town
# Processing Record 111 of Set 1 | meulaboh
# Processing Record 112 of Set 1 | yarada
# Processing Record 113 of Set 1 | pontian kecil
# Processing Record 114 of Set 1 | beloha
# Processing Record 115 of Set 1 | maningrida
# Processing Record 116 of Set 1 | boyolangu
# Processing Record 117 of Set 1 | port hardy
# Processing Record 118 of Set 1 | sabang
# Processing Record 119 of Set 1 | verkhnevilyuysk
# Processing Record 120 of Set 1 | jacqueville
# Processing Record 121 of Set 1 | pirovskoye
# Processing Record 122 of Set 1 | cayenne
# Processing Record 123 of Set 1 | dikson
# Processing Record 124 of Set 1 | lokosovo
# Processing Record 125 of Set 1 | antalaha
# Processing Record 126 of Set 1 | puerto ayora
# The city of bengkulu was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 127 of Set 1 | cherskiy
# Processing Record 128 of Set 1 | bireun
# Processing Record 129 of Set 1 | narsaq
# Processing Record 130 of Set 1 | prince rupert
# Processing Record 131 of Set 1 | umm lajj
# Processing Record 132 of Set 1 | praia da vitoria
# Processing Record 133 of Set 1 | vestmannaeyjar
# Processing Record 134 of Set 1 | fray bentos
# Processing Record 135 of Set 1 | provideniya
# Processing Record 136 of Set 1 | gravdal
# Processing Record 137 of Set 1 | sur
# Processing Record 138 of Set 1 | wuwei
# Processing Record 139 of Set 1 | pisco
# The city of nizhneyansk was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 140 of Set 1 | yuzha
# Processing Record 141 of Set 1 | airai
# Processing Record 142 of Set 1 | suslovo
# Processing Record 143 of Set 1 | bambanglipuro
# Processing Record 144 of Set 1 | luderitz
# Processing Record 145 of Set 1 | yar-sale
# The city of mys shmidta was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 146 of Set 1 | alyangula
# Processing Record 147 of Set 1 | macapa
# Processing Record 148 of Set 1 | broken hill
# The city of barentsburg was not found! Skipping. Error code was HTTP Error 404: Not Found
# The city of illoqqortoormiut was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 149 of Set 1 | mahon
# Processing Record 150 of Set 1 | nikolskoye
# Processing Record 151 of Set 1 | manono
# Processing Record 152 of Set 1 | swan hill
# Processing Record 153 of Set 1 | zhigansk
# Processing Record 154 of Set 1 | porto novo
# The city of umzimvubu was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 155 of Set 1 | amahai
# The city of korla was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 156 of Set 1 | merauke
# Processing Record 157 of Set 1 | wasilla
# Processing Record 158 of Set 1 | vostok
# Processing Record 159 of Set 1 | bredasdorp
# Processing Record 160 of Set 1 | lagoa
# Processing Record 161 of Set 1 | erzin
# Processing Record 162 of Set 1 | lavrentiya
# Processing Record 163 of Set 1 | tessalit
# Processing Record 164 of Set 1 | mogadishu
# Processing Record 165 of Set 1 | pontes e lacerda
# Processing Record 166 of Set 1 | longyearbyen
# Processing Record 167 of Set 1 | bonthe
# Processing Record 168 of Set 1 | walvis bay
# Processing Record 169 of Set 1 | tuktoyaktuk
# The city of jiddah was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 170 of Set 1 | santiago del estero
# Processing Record 171 of Set 1 | nishihara
# Processing Record 172 of Set 1 | ayan
# Processing Record 173 of Set 1 | nyurba
# Processing Record 174 of Set 1 | ulaangom
# Processing Record 175 of Set 1 | ponta do sol
# Processing Record 176 of Set 1 | toucheng
# Processing Record 177 of Set 1 | yulara
# The city of belushya guba was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 178 of Set 1 | vysokogornyy
# Processing Record 179 of Set 1 | westport
# Processing Record 180 of Set 1 | cabra
# Processing Record 181 of Set 1 | farafangana
# Processing Record 182 of Set 1 | saint-joseph
# Processing Record 183 of Set 1 | saint anthony
# Processing Record 184 of Set 1 | bereda
# Processing Record 185 of Set 1 | maputo
# Processing Record 186 of Set 1 | kolyvan
# Processing Record 187 of Set 1 | hithadhoo
# Processing Record 188 of Set 1 | akureyri
# Processing Record 189 of Set 1 | saldanha
# Processing Record 190 of Set 1 | edgewater
# Processing Record 191 of Set 1 | ptuj
# Processing Record 192 of Set 1 | yaan
# Processing Record 193 of Set 1 | yablonovo
# Processing Record 194 of Set 1 | nome
# Processing Record 195 of Set 1 | wenling
# Processing Record 196 of Set 1 | mahebourg
# The city of pilao arcado was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 197 of Set 1 | vardo
# Processing Record 198 of Set 1 | macia
# Processing Record 199 of Set 1 | esik
# Processing Record 200 of Set 1 | ucluelet
# Processing Record 201 of Set 1 | qingquan
# Processing Record 202 of Set 1 | quelimane
# Processing Record 203 of Set 1 | tautira
# Processing Record 204 of Set 1 | lompoc
# Processing Record 205 of Set 1 | coffs harbour
# Processing Record 206 of Set 1 | ormara
# The city of arrecife was not found! Skipping. Error code was HTTP Error 404: Not Found
# The city of mrirt was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 207 of Set 1 | marechal deodoro
# The city of qui nhon was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 208 of Set 1 | guerrero negro
# Processing Record 209 of Set 1 | beringovskiy
# Processing Record 210 of Set 1 | ingham
# Processing Record 211 of Set 1 | susehri
# Processing Record 212 of Set 1 | lagos
# Processing Record 213 of Set 1 | torbay
# The city of vaitupu was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 214 of Set 1 | solenzo
# Processing Record 215 of Set 1 | santa maria
# Processing Record 216 of Set 1 | zakharovo
# Processing Record 217 of Set 1 | salaverry
# Processing Record 218 of Set 1 | faanui
# Processing Record 219 of Set 1 | khatanga
# Processing Record 220 of Set 1 | naryan-mar
# Processing Record 221 of Set 1 | shingu
# Processing Record 222 of Set 1 | ati
# The city of krasnoselkup was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 223 of Set 1 | rabaul
# Processing Record 224 of Set 1 | husavik
# The city of olafsvik was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 225 of Set 1 | codrington
# Processing Record 226 of Set 1 | lazaro cardenas
# Processing Record 227 of Set 1 | mozarlandia
# Processing Record 228 of Set 1 | peleduy
# Processing Record 229 of Set 1 | mandera
# Processing Record 230 of Set 1 | la palma
# The city of andenes was not found! Skipping. Error code was HTTP Error 404: Not Found
# The city of bargal was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 231 of Set 1 | san carlos de bariloche
# Processing Record 232 of Set 1 | kirakira
# Processing Record 233 of Set 1 | sitka
# Processing Record 234 of Set 1 | yaya
# Processing Record 235 of Set 1 | baherden
# Processing Record 236 of Set 1 | indian head
# Processing Record 237 of Set 1 | abu samrah
# Processing Record 238 of Set 1 | george
# The city of halalo was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 239 of Set 1 | abrau-dyurso
# Processing Record 240 of Set 1 | flinders
# Processing Record 241 of Set 1 | arraial do cabo
# Processing Record 242 of Set 1 | alghero
# Processing Record 243 of Set 1 | zeya
# Processing Record 244 of Set 1 | rocha
# Processing Record 245 of Set 1 | yellowknife
# Processing Record 246 of Set 1 | komsomolskiy
# Processing Record 247 of Set 1 | goderich
# Processing Record 248 of Set 1 | abu kamal
# Processing Record 249 of Set 1 | banepa
# The city of tumannyy was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 250 of Set 1 | makat
# Processing Record 251 of Set 1 | norrkoping
# Processing Record 252 of Set 1 | turayf
# Processing Record 253 of Set 1 | iqaluit
# Processing Record 254 of Set 1 | villa carlos paz
# Processing Record 255 of Set 1 | saint-francois
# Processing Record 256 of Set 1 | alice springs
# Processing Record 257 of Set 1 | bubaque
# Processing Record 258 of Set 1 | deqing
# Processing Record 259 of Set 1 | huancabamba
# Processing Record 260 of Set 1 | ivanava
# Processing Record 261 of Set 1 | nanortalik
# Processing Record 262 of Set 1 | udachnyy
# Processing Record 263 of Set 1 | chancay
# Processing Record 264 of Set 1 | kibakwe
# Processing Record 265 of Set 1 | grand-santi
# Processing Record 266 of Set 1 | behbahan
# Processing Record 267 of Set 1 | vila franca do campo
# Processing Record 268 of Set 1 | bourail
# Processing Record 269 of Set 1 | bundaberg
# Processing Record 270 of Set 1 | rovaniemi
# Processing Record 271 of Set 1 | lafia
# Processing Record 272 of Set 1 | xinxiang
# Processing Record 273 of Set 1 | omboue
# Processing Record 274 of Set 1 | kahului
# Processing Record 275 of Set 1 | thompson
# Processing Record 276 of Set 1 | jumla
# Processing Record 277 of Set 1 | bathsheba
# Processing Record 278 of Set 1 | okhotsk
# Processing Record 279 of Set 1 | ancud
# Processing Record 280 of Set 1 | roald
# Processing Record 281 of Set 1 | upernavik
# Processing Record 282 of Set 1 | kloulklubed
# Processing Record 283 of Set 1 | fujin
# Processing Record 284 of Set 1 | dhanwar
# Processing Record 285 of Set 1 | arlit
# Processing Record 286 of Set 1 | shiyan
# Processing Record 287 of Set 1 | kieta
# Processing Record 288 of Set 1 | anadyr
# The city of lolua was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 289 of Set 1 | pokosnoye
# Processing Record 290 of Set 1 | gamba
# Processing Record 291 of Set 1 | dingle
# Processing Record 292 of Set 1 | karatuzskoye
# Processing Record 293 of Set 1 | mantua
# The city of cambyreta was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 294 of Set 1 | suratgarh
# The city of yanchukan was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 295 of Set 1 | nouadhibou
# Processing Record 296 of Set 1 | bambous virieux
# Processing Record 297 of Set 1 | camacha
# Processing Record 298 of Set 1 | enid
# Processing Record 299 of Set 1 | denham springs
# Processing Record 300 of Set 1 | ostrovnoy
# Processing Record 301 of Set 1 | boa vista
# Processing Record 302 of Set 1 | hofn
# The city of jabiru was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 303 of Set 1 | yumen
# Processing Record 304 of Set 1 | port keats
# Processing Record 305 of Set 1 | tarauaca
# Processing Record 306 of Set 1 | bose
# Processing Record 307 of Set 1 | chaihe
# Processing Record 308 of Set 1 | biak
# Processing Record 309 of Set 1 | isangel
# Processing Record 310 of Set 1 | wewak
# Processing Record 311 of Set 1 | kruisfontein
# Processing Record 312 of Set 1 | novyy urengoy
# Processing Record 313 of Set 1 | bam
# Processing Record 314 of Set 1 | port lincoln
# Processing Record 315 of Set 1 | port-gentil
# Processing Record 316 of Set 1 | fort nelson
# Processing Record 317 of Set 1 | romitan
# The city of karpuninskiy was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 318 of Set 1 | sorong
# Processing Record 319 of Set 1 | lebu
# Processing Record 320 of Set 1 | zinder
# Processing Record 321 of Set 1 | severo-yeniseyskiy
# Processing Record 322 of Set 1 | port moresby
# Processing Record 323 of Set 1 | portland
# Processing Record 324 of Set 1 | santa isabel do rio negro
# Processing Record 325 of Set 1 | datong
# Processing Record 326 of Set 1 | saint joseph
# Processing Record 327 of Set 1 | kingsport
# Processing Record 328 of Set 1 | vyshneve
# Processing Record 329 of Set 1 | kunda
# Processing Record 330 of Set 1 | touros
# Processing Record 331 of Set 1 | tallahassee
# Processing Record 332 of Set 1 | petrovskoye
# Processing Record 333 of Set 1 | port blair
# The city of urumqi was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 334 of Set 1 | haines junction
# Processing Record 335 of Set 1 | bethel
# Processing Record 336 of Set 1 | cidreira
# Processing Record 337 of Set 1 | imperia
# The city of muzquiz was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 338 of Set 1 | trincomalee
# Processing Record 339 of Set 1 | weatherford
# Processing Record 340 of Set 1 | chara
# Processing Record 341 of Set 1 | uige
# Processing Record 342 of Set 1 | dauphin
# Processing Record 343 of Set 1 | show low
# Processing Record 344 of Set 1 | necochea
# Processing Record 345 of Set 1 | kayerkan
# Processing Record 346 of Set 1 | salalah
# Processing Record 347 of Set 1 | taoudenni
# Processing Record 348 of Set 1 | parambu
# Processing Record 349 of Set 1 | kagal
# Processing Record 350 of Set 1 | aswan
# Processing Record 351 of Set 1 | duncan
# Processing Record 352 of Set 1 | fortuna
# Processing Record 353 of Set 1 | destin
# Processing Record 354 of Set 1 | srivardhan
# Processing Record 355 of Set 1 | port macquarie
# Processing Record 356 of Set 1 | ampanihy
# Processing Record 357 of Set 1 | lima
# Processing Record 358 of Set 1 | mount gambier
# Processing Record 359 of Set 1 | moindou
# Processing Record 360 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 361 of Set 1 | havre-saint-pierre
# Processing Record 362 of Set 1 | williston
# Processing Record 363 of Set 1 | rapid valley
# Processing Record 364 of Set 1 | srednekolymsk
# Processing Record 365 of Set 1 | san patricio
# Processing Record 366 of Set 1 | kharp
# Processing Record 367 of Set 1 | sinnamary
# Processing Record 368 of Set 1 | mumford
# Processing Record 369 of Set 1 | egvekinot
# Processing Record 370 of Set 1 | cockburn town
# Processing Record 371 of Set 1 | namatanai
# Processing Record 372 of Set 1 | la rioja
# Processing Record 373 of Set 1 | mauriti
# The city of labrea was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 374 of Set 1 | turukhansk
# Processing Record 375 of Set 1 | kajaani
# Processing Record 376 of Set 1 | poya
# Processing Record 377 of Set 1 | novosheshminsk
# Processing Record 378 of Set 1 | kampot
# Processing Record 379 of Set 1 | bone
# Processing Record 380 of Set 1 | talara
# Processing Record 381 of Set 1 | wanning
# Processing Record 382 of Set 1 | manta
# Processing Record 383 of Set 1 | naushki
# Processing Record 384 of Set 1 | namibe
# Processing Record 385 of Set 1 | constitucion
# Processing Record 386 of Set 1 | cap malheureux
# Processing Record 387 of Set 1 | black river
# Processing Record 388 of Set 1 | jucurutu
# Processing Record 389 of Set 1 | mao
# Processing Record 390 of Set 1 | bud
# Processing Record 391 of Set 1 | puruliya
# Processing Record 392 of Set 1 | belle fourche
# Processing Record 393 of Set 1 | ust-koksa
# Processing Record 394 of Set 1 | morros
# Processing Record 395 of Set 1 | beaverlodge
# Processing Record 396 of Set 1 | clyde river
# Processing Record 397 of Set 1 | mago
# Processing Record 398 of Set 1 | wakkanai
# Processing Record 399 of Set 1 | chinsali
# Processing Record 400 of Set 1 | tornio
# Processing Record 401 of Set 1 | estelle
# Processing Record 402 of Set 1 | la asuncion
# Processing Record 403 of Set 1 | mandalgovi
# Processing Record 404 of Set 1 | maldonado
# Processing Record 405 of Set 1 | ikalamavony
# Processing Record 406 of Set 1 | dhidhdhoo
# Processing Record 407 of Set 1 | olga
# Processing Record 408 of Set 1 | omaruru
# Processing Record 409 of Set 1 | quang ngai
# Processing Record 410 of Set 1 | sijunjung
# Processing Record 411 of Set 1 | kirkuk
# Processing Record 412 of Set 1 | rylsk
# Processing Record 413 of Set 1 | gulbene
# Processing Record 414 of Set 1 | escanaba
# Processing Record 415 of Set 1 | saint george
# Processing Record 416 of Set 1 | reinosa
# Processing Record 417 of Set 1 | williams lake
# Processing Record 418 of Set 1 | bayan
# Processing Record 419 of Set 1 | regeneracao
# Processing Record 420 of Set 1 | quatre cocos
# Processing Record 421 of Set 1 | santo amaro da imperatriz
# Processing Record 422 of Set 1 | america dourada
# Processing Record 423 of Set 1 | santa marta
# Processing Record 424 of Set 1 | kroya
# Processing Record 425 of Set 1 | curvelo
# Processing Record 426 of Set 1 | camopi
# The city of arkhangelos was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 427 of Set 1 | ahipara
# Processing Record 428 of Set 1 | port hawkesbury
# Processing Record 429 of Set 1 | batticaloa
# Processing Record 430 of Set 1 | kang
# Processing Record 431 of Set 1 | sao paulo de olivenca
# Processing Record 432 of Set 1 | saint-augustin
# Processing Record 433 of Set 1 | rottenmann
# Processing Record 434 of Set 1 | filomeno mata
# Processing Record 435 of Set 1 | sao miguel do iguacu
# Processing Record 436 of Set 1 | caconda
# Processing Record 437 of Set 1 | halifax
# Processing Record 438 of Set 1 | buriti bravo
# Processing Record 439 of Set 1 | padang
# Processing Record 440 of Set 1 | parintins
# Processing Record 441 of Set 1 | takoradi
# Processing Record 442 of Set 1 | avera
# Processing Record 443 of Set 1 | tucuru
# Processing Record 444 of Set 1 | nacozari
# Processing Record 445 of Set 1 | urucara
# Processing Record 446 of Set 1 | byron bay
# Processing Record 447 of Set 1 | kango
# The city of saleaula was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 448 of Set 1 | virginia beach
# Processing Record 449 of Set 1 | sobolevo
# Processing Record 450 of Set 1 | hobyo
# Processing Record 451 of Set 1 | marsabit
# Processing Record 452 of Set 1 | glendive
# Processing Record 453 of Set 1 | rustenburg
# Processing Record 454 of Set 1 | sawakin
# Processing Record 455 of Set 1 | hovd
# Processing Record 456 of Set 1 | tacoronte
# Processing Record 457 of Set 1 | pedasi
# Processing Record 458 of Set 1 | oktyabrskiy
# Processing Record 459 of Set 1 | lewistown
# Processing Record 460 of Set 1 | pahrump
# Processing Record 461 of Set 1 | verkhneyarkeyevo
# Processing Record 462 of Set 1 | idritsa
# Processing Record 463 of Set 1 | rivne
# Processing Record 464 of Set 1 | hasaki
# The city of sorvag was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 465 of Set 1 | lugoba
# Processing Record 466 of Set 1 | simpang
# Processing Record 467 of Set 1 | falam
# Processing Record 468 of Set 1 | nahariyya
# Processing Record 469 of Set 1 | kasane
# Processing Record 470 of Set 1 | olinda
# Processing Record 471 of Set 1 | ocampo
# Processing Record 472 of Set 1 | mbandaka
# Processing Record 473 of Set 1 | ha tinh
# Processing Record 474 of Set 1 | grindavik
# Processing Record 475 of Set 1 | sal rei
# Processing Record 476 of Set 1 | svetlaya
# Processing Record 477 of Set 1 | tortoli
# Processing Record 478 of Set 1 | jacareacanga
# Processing Record 479 of Set 1 | yairipok
# Processing Record 480 of Set 1 | ulladulla
# Processing Record 481 of Set 1 | hualmay
# Processing Record 482 of Set 1 | lasa
# The city of utiroa was not found! Skipping. Error code was HTTP Error 404: Not Found
# The city of tawkar was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 483 of Set 1 | lakatoro
# Processing Record 484 of Set 1 | sindou
# Processing Record 485 of Set 1 | mwinilunga
# Processing Record 486 of Set 1 | agarak
# The city of bababe was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 487 of Set 1 | progreso
# Processing Record 488 of Set 1 | jining
# Processing Record 489 of Set 1 | north bend
# Processing Record 490 of Set 1 | tateyama
# Processing Record 491 of Set 1 | itarema
# Processing Record 492 of Set 1 | riberalta
# The city of garm was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 493 of Set 1 | znamenskoye
# Processing Record 494 of Set 1 | monroe
# Processing Record 495 of Set 1 | santo domingo
# The city of bajo baudo was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 496 of Set 1 | marawi
# Processing Record 497 of Set 1 | vanavara
# Processing Record 498 of Set 1 | kokorevka
# Processing Record 499 of Set 1 | kilis
# The city of sakakah was not found! Skipping. Error code was HTTP Error 404: Not Found
# The city of felidhoo was not found! Skipping. Error code was HTTP Error 404: Not Found
# The city of lephepe was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 500 of Set 1 | maceio
# The city of ituni was not found! Skipping. Error code was HTTP Error 404: Not Found
# The city of kegayli was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 501 of Set 1 | khonsa
# Processing Record 502 of Set 1 | kondinskoye
# Processing Record 503 of Set 1 | carupano
# Processing Record 504 of Set 1 | lucapa
# Processing Record 505 of Set 1 | bordeaux
# Processing Record 506 of Set 1 | gornopravdinsk
# Processing Record 507 of Set 1 | yantzaza
# The city of mutsamudu was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 508 of Set 1 | yeniseysk
# Processing Record 509 of Set 1 | ust-tsilma
# Processing Record 510 of Set 1 | kudahuvadhoo
# Processing Record 511 of Set 1 | labuhan
# Processing Record 512 of Set 1 | west milford
# Processing Record 513 of Set 1 | kultayevo
# Processing Record 514 of Set 1 | kargasok
# Processing Record 515 of Set 1 | guliston
# Processing Record 516 of Set 1 | laguna
# Processing Record 517 of Set 1 | buraydah
# Processing Record 518 of Set 1 | swellendam
# Processing Record 519 of Set 1 | saint-pierre
# The city of sento se was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 520 of Set 1 | nelson bay
# Processing Record 521 of Set 1 | las vegas
# Processing Record 522 of Set 1 | christchurch
# Processing Record 523 of Set 1 | schongau
# Processing Record 524 of Set 1 | corrente
# Processing Record 525 of Set 1 | obera
# Processing Record 526 of Set 1 | muscat
# Processing Record 527 of Set 1 | atar
# Processing Record 528 of Set 1 | san cristobal
# Processing Record 529 of Set 1 | bandarbeyla
# Processing Record 530 of Set 1 | mariel
# Processing Record 531 of Set 1 | jiangyou
# Processing Record 532 of Set 1 | oyem
# Processing Record 533 of Set 1 | port-cartier
# Processing Record 534 of Set 1 | limerick
# Processing Record 535 of Set 1 | puerto colombia
# Processing Record 536 of Set 1 | debno
# Processing Record 537 of Set 1 | wattegama
# The city of umm ruwabah was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 538 of Set 1 | muli
# Processing Record 539 of Set 1 | slave lake
# Processing Record 540 of Set 1 | champerico
# The city of kerteh was not found! Skipping. Error code was HTTP Error 404: Not Found
# The city of saryshagan was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 541 of Set 1 | sangar
# Processing Record 542 of Set 1 | sao mateus
# Processing Record 543 of Set 1 | jalu
# Processing Record 544 of Set 1 | suileng
# Processing Record 545 of Set 1 | deniliquin
# Processing Record 546 of Set 1 | harper
# Processing Record 547 of Set 1 | mayskiy
# Processing Record 548 of Set 1 | talavera
# Processing Record 549 of Set 1 | qobustan
# Processing Record 550 of Set 1 | carballo
# Processing Record 551 of Set 1 | sibolga
# Processing Record 552 of Set 1 | sualkuchi
# Processing Record 553 of Set 1 | hay river
# Processing Record 554 of Set 1 | shimoda
# The city of linshu was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 555 of Set 1 | bilkha
# Processing Record 556 of Set 1 | anloga
# Processing Record 557 of Set 1 | sagaing
# Processing Record 558 of Set 1 | manokwari
# Processing Record 559 of Set 1 | kaeo
# Processing Record 560 of Set 1 | dickinson
# Processing Record 561 of Set 1 | caravelas
# Processing Record 562 of Set 1 | ankang
# Processing Record 563 of Set 1 | taksimo
# The city of haademeeste was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 564 of Set 1 | lorengau
# Processing Record 565 of Set 1 | iquique
# The city of kuche was not found! Skipping. Error code was HTTP Error 404: Not Found
# Processing Record 566 of Set 1 | luanda
# Processing Record 567 of Set 1 | rio gallegos
# Processing Record 568 of Set 1 | natal
# The OpenWeather API data dump is complete.

# %%
#test out data dump
#print(weather_data)

# %%
column_names = ["City","Country","Date","Max Temperature(F)","Humidity","Cloudiness","Wind Speed(mph)","Latitude","Longitude"]
weather_df = pd.DataFrame(weather_data,columns=column_names)
weather_df.dtypes
# Out:
# City                   object
# Country                object
# Date                    int64
# Max Temperature(F)    float64
# Humidity                int64
# Cloudiness              int64
# Wind Speed(mph)       float64
# Latitude              float64
# Longitude             float64
# dtype: object

# %%
#using the time function we are able to translate the unixtime stamp to a more readable date that can be applied to our file 
date = weather_df["Date"][0]
date_format = time.strftime("%m/%d/%Y", time.localtime(date))
date_format
# Out:
# '03/23/2019'

# %%
#Wrapper test
#city_weather = owm.get_current(cities[0], **settings)
#city_weather

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#convert our df to a csv file 
weather_df.to_csv(city_weather_data, encoding="utf-8", index=False)

# %%
#show data frame
weather_df.head()
# Out:
#              City Country        Date  Max Temperature(F)  Humidity  \
# 0            Chuy      UY  1553372474               72.18        79
# 1         Rikitea      PF  1553372441               79.65        97
# 2           Derac      HT  1553367600               82.40        65
# 3       Jamestown      AU  1553372230               64.26        86
# 4  Severo-Kurilsk      RU  1553372475               29.97        99
#
#    Cloudiness  Wind Speed(mph)  Latitude  Longitude
# 0           0             6.64    -33.69     -53.46
# 1          64            19.28    -23.12    -134.97
# 2          20            16.11     19.65     -71.82
# 3          92            10.45    -33.21     138.60
# 4          80            16.49     50.68     156.12

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#create scatter plot Latitude vs.Temperature using pandas plot

weather_df.plot.scatter(x="Latitude", y='Max Temperature(F)', grid=True, 
                               alpha=1, edgecolors ='black', title = f"City Latitude vs Max Temperature(F)({date_format})")
#test plot
plt.plot()
#savefit
plt.savefig("../Images/lat_maxtemp.png")
#show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#create scatter plot Latitude vs.Temperature using pandas plot

weather_df.plot.scatter(x="Latitude", y='Humidity', grid=True, 
                               alpha=1, edgecolors ='black', title = f"City Latitude vs Humidity({date_format})")
#test plot
plt.plot()
#savefit
plt.savefig("../Images/lat_humidity.png")
#show plot
plt.show()

# %%
#There is an outlier in the data set above with a humidity above 100%
#Talara, Peru is listed with a Humidity of above 100
humidity_df= weather_df.sort_values(by='Humidity', ascending=False)
humidity_df.head()
# Out:
#            City Country        Date  Max Temperature(F)  Humidity  Cloudiness  \
# 379      Talara      PE  1553367600               62.60       290           0
# 471    Mbandaka      CD  1553372599               73.17       100          36
# 161  Lavrentiya      RU  1553372515               15.30       100          92
# 209      Ingham      AU  1553372528               79.20       100          88
# 472     Ha Tinh      VN  1553372599               70.83       100          88
#
#      Wind Speed(mph)  Latitude  Longitude
# 379            12.12     -4.58     -81.27
# 471             2.39      0.05      18.26
# 161            12.80     65.58    -170.99
# 209             9.22    -18.65     146.16
# 472            19.73     18.33     105.90

# %%
#We remove the outlier and create a new graph for better representation

humidity_df= weather_df.sort_values(by='Humidity', ascending=False)
humidity_clean_df = humidity_df[humidity_df["Humidity"]<=100]

#create scatter plot Latitude vs.Temperature using pandas plot

humidity_clean_df.plot.scatter(x="Latitude", y='Humidity', grid=True, 
                               alpha=1, edgecolors ='black', title = f"City Latitude vs Humidity({date_format})")
#test plot
plt.plot()
#savefit
plt.savefig("../Images/lat_humidity_no_outlier.png")
#show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#create scatter plot Latitude vs.Temperature using pandas plot

weather_df.plot.scatter(x="Latitude", y='Cloudiness', grid=True, 
                               alpha=1, edgecolors ='black', title = f"City Latitude vs Cloudiness({date_format})")
#test plot
plt.plot()
#savefit
plt.savefig("../Images/lat_cloudiness.png")
#show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#create scatter plot Latitude vs.Temperature using pandas plot

weather_df.plot.scatter(x="Latitude", y='Wind Speed(mph)', grid=True, 
                               alpha=1, edgecolors ='black', title = f"City Latitude vs Windspeed(mph) ({date_format})")
#test plot
plt.plot()
#savefit
plt.savefig("../Images/lat_windspeed.png")
#show plot
plt.show()
